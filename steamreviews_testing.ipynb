# %%
import steamreviews
import pandas as pd
import prepare as p
import explore as e
import importlib

# %%
app_ids = [329070, 573170]
steamreviews.download_reviews_for_app_id_batch(app_ids)
# Out:
# Loading idprocessed_on_20230122.txt
# Creating idprocessed_on_20230122.txt
# ...
# [appID = 329070] expected #reviews = 1209
# [appID = 329070] num_reviews = 1209 (expected: 1209)
# ...
# [appID = 573170] expected #reviews = 378
# [appID = 573170] num_reviews = 378 (expected: 378)
# Game records written: 2
# True

# %%
df1 = pd.read_json('data/review_573170.json')

# %%
df1
# Out:
#                                                                 reviews  \
# 131299060             {'recommendationid': '131299060', 'author': {'...
# 125559318             {'recommendationid': '125559318', 'author': {'...
# 123786795             {'recommendationid': '123786795', 'author': {'...
# 123340074             {'recommendationid': '123340074', 'author': {'...
# 122702651             {'recommendationid': '122702651', 'author': {'...
# ...                                                                 ...
# review_score_desc                                                   NaN
# total_positive                                                      NaN
# total_negative                                                      NaN
# total_reviews                                                       NaN
# AoJw9/3Rz90CcYbEgQE=                                                NaN
#
#                       query_summary                   cursors
# ...

# %%
df1_rev = df1.reviews

# %%
df1_rev = df1_rev.dropna()

# %%
df1_rev = pd.DataFrame(df1_rev)

# %%
df1_rev
# Out:
#                                                      reviews
# 131299060  {'recommendationid': '131299060', 'author': {'...
# 125559318  {'recommendationid': '125559318', 'author': {'...
# 123786795  {'recommendationid': '123786795', 'author': {'...
# 123340074  {'recommendationid': '123340074', 'author': {'...
# 122702651  {'recommendationid': '122702651', 'author': {'...
# ...                                                      ...
# 33957655   {'recommendationid': '33957655', 'author': {'s...
# 33957135   {'recommendationid': '33957135', 'author': {'s...
# 33956399   {'recommendationid': '33956399', 'author': {'s...
# 33956365   {'recommendationid': '33956365', 'author': {'s...
# 33955937   {'recommendationid': '33955937', 'author': {'s...
#
# [378 rows x 1 columns]

# %%
new_df = pd.DataFrame.from_dict(df1_rev.reviews)

# %%
new_df.reviews
# Out:
# 131299060    {'recommendationid': '131299060', 'author': {'...
# 125559318    {'recommendationid': '125559318', 'author': {'...
# 123786795    {'recommendationid': '123786795', 'author': {'...
# 123340074    {'recommendationid': '123340074', 'author': {'...
# 122702651    {'recommendationid': '122702651', 'author': {'...
#                                    ...
# 33957655     {'recommendationid': '33957655', 'author': {'s...
# 33957135     {'recommendationid': '33957135', 'author': {'s...
# 33956399     {'recommendationid': '33956399', 'author': {'s...
# 33956365     {'recommendationid': '33956365', 'author': {'s...
# 33955937     {'recommendationid': '33955937', 'author': {'s...
# Name: reviews, Length: 378, dtype: object

# %%
list(new_df.reviews)
# Out:
# [{'recommendationid': '131299060',
#   'author': {'steamid': '76561198020567638',
#    'num_games_owned': 601,
#    'num_reviews': 56,
#    'playtime_forever': 264,
#    'playtime_last_two_weeks': 14,
#    'playtime_at_review': 264,
#    'last_played': 1674339410},
#   'language': 'english',
#   'review': "beautiful visuals, argentinean dev and tight game design (only has the exact elements it needs to work nicely)\n\ni used to get extremely frustrated at this game, but recently the dev implemented a more forgiving death mechanic and it's much much better!\n\ngo for it!",
#   'timestamp_created': 1674339628,
#   'timestamp_updated': 1674339628,
#   'voted_up': True,
#   'votes_up': 0,
#   'votes_funny': 0,
#   'weighted_vote_score': 0,
#   'comment_count': 0,
#   'steam_purchase': False,
#   'received_for_free': False,
#   'written_during_early_access': False,
#   'hidden_in_steam_china': True,
#   'steam_china_location': ''},
#  {'recommendationid': '125559318',
# ...

# %%
dict(new_df.reviews)
# Out:
# {'131299060': {'recommendationid': '131299060',
#   'author': {'steamid': '76561198020567638',
#    'num_games_owned': 601,
#    'num_reviews': 56,
#    'playtime_forever': 264,
#    'playtime_last_two_weeks': 14,
#    'playtime_at_review': 264,
#    'last_played': 1674339410},
#   'language': 'english',
#   'review': "beautiful visuals, argentinean dev and tight game design (only has the exact elements it needs to work nicely)\n\ni used to get extremely frustrated at this game, but recently the dev implemented a more forgiving death mechanic and it's much much better!\n\ngo for it!",
#   'timestamp_created': 1674339628,
#   'timestamp_updated': 1674339628,
#   'voted_up': True,
#   'votes_up': 0,
#   'votes_funny': 0,
#   'weighted_vote_score': 0,
#   'comment_count': 0,
#   'steam_purchase': False,
#   'received_for_free': False,
#   'written_during_early_access': False,
#   'hidden_in_steam_china': True,
#   'steam_china_location': ''},
# ...

# %%
pd.DataFrame(dict(new_df.reviews)).T
# Out:
#           recommendationid                                             author  \
# 131299060        131299060  {'steamid': '76561198020567638', 'num_games_ow...
# 125559318        125559318  {'steamid': '76561198111765120', 'num_games_ow...
# 123786795        123786795  {'steamid': '76561198110034812', 'num_games_ow...
# 123340074        123340074  {'steamid': '76561198121420845', 'num_games_ow...
# 122702651        122702651  {'steamid': '76561197977597227', 'num_games_ow...
# ...                    ...                                                ...
# 33957655          33957655  {'steamid': '76561198027476482', 'num_games_ow...
# 33957135          33957135  {'steamid': '76561197996417403', 'num_games_ow...
# 33956399          33956399  {'steamid': '76561198001965099', 'num_games_ow...
# 33956365          33956365  {'steamid': '76561198047211746', 'num_games_ow...
# 33955937          33955937  {'steamid': '76561198070703061', 'num_games_ow...
#
# ...

# %%
df = pd.DataFrame(dict(new_df.reviews)).T

# %%
df
# Out:
#           recommendationid                                             author  \
# 131299060        131299060  {'steamid': '76561198020567638', 'num_games_ow...
# 125559318        125559318  {'steamid': '76561198111765120', 'num_games_ow...
# 123786795        123786795  {'steamid': '76561198110034812', 'num_games_ow...
# 123340074        123340074  {'steamid': '76561198121420845', 'num_games_ow...
# 122702651        122702651  {'steamid': '76561197977597227', 'num_games_ow...
# ...                    ...                                                ...
# 33957655          33957655  {'steamid': '76561198027476482', 'num_games_ow...
# 33957135          33957135  {'steamid': '76561197996417403', 'num_games_ow...
# 33956399          33956399  {'steamid': '76561198001965099', 'num_games_ow...
# 33956365          33956365  {'steamid': '76561198047211746', 'num_games_ow...
# 33955937          33955937  {'steamid': '76561198070703061', 'num_games_ow...
#
# ...

# %%
df2 = pd.read_json('data/review_329070.json')

# %%
spyparty = pd.DataFrame(dict(df2.reviews)).T

# %%
spyparty
# Out:
#                      recommendationid  \
# 131316636                   131316636
# 131276824                   131276824
# 131262353                   131262353
# 131011558                   131011558
# 131011436                   131011436
# ...                               ...
# review_score_desc                 NaN
# total_positive                    NaN
# total_negative                    NaN
# total_reviews                     NaN
# AoJ4g87V3eICcJiKngE=              NaN
#
#                                                                  author  \
# 131316636             {'steamid': '76561199115781016', 'num_games_ow...
# 131276824             {'steamid': '76561199330181211', 'num_games_ow...
# 131262353             {'steamid': '76561198996420008', 'num_games_ow...
# 131011558             {'steamid': '76561199347752915', 'num_games_ow...
# 131011436             {'steamid': '76561199329857288', 'num_games_ow...
# ...

# %%
df = pd.read_csv('app_list.csv')
#df = df.appid.astype(int).astype(str)

# %%
df['appid'] = df.appid.astype(int)

# %%
app_list = list(df.appid)

# %%
app_list
# Out:
# [10,
#  20,
#  30,
#  40,
#  50,
#  60,
#  70,
#  80,
#  130,
#  220,
#  240,
#  280,
#  300,
#  320,
#  340,
#  360,
#  380,
#  400,
#  420,
#  440,
#  500,
#  550,
#  570,
#  620,
#  630,
#  730,
#  1002,
#  1200,
#  1250,
#  1300,
#  1313,
#  1500,
#  1510,
#  1520,
#  1530,
#  1600,
#  1610,
#  1620,
#  1630,
#  1640,
#  1670,
#  1690,
#  1700,
#  1900,
#  1930,
#  2100,
#  2200,
#  2210,
#  2270,
#  2280,
#  2290,
#  2300,
#  2310,
#  2320,
#  2330,
#  2340,
#  2350,
#  2360,
#  2370,
#  2390,
#  2400,
#  2420,
#  2450,
#  2500,
#  2520,
#  2540,
#  2570,
#  2590,
#  2600,
#  2610,
#  2620,
#  2630,
#  2640,
#  2700,
#  2710,
#  2720,
#  2780,
#  2800,
#  2810,
#  2820,
#  2840,
#  2850,
#  2870,
#  2900,
#  2910,
#  2920,
#  2990,
#  3010,
#  3020,
#  3050,
#  3130,
#  3170,
#  3230,
#  3260,
#  3270,
#  3300,
#  3310,
#  3320,
#  3330,
#  3340,
#  3350,
#  3360,
#  3380,
#  3390,
#  3400,
#  3410,
#  3420,
#  3430,
#  3450,
#  3460,
#  3480,
#  3483,
#  3490,
#  3500,
# ...

# %%
# CS:GO, Destiny 2, Lost Ark, Skyrim SE, Apex Legends
app_list_specific = [730, 1085660, 1599340, 489830, 1172470]

# %%
request_params = dict()
# Reference: https://partner.steamgames.com/doc/store/localization#supported_languages
request_params['language'] = 'english'
# Reference: https://partner.steamgames.com/doc/store/getreviews
#request_params['review_type'] = 'positive'
request_params['purchase_type'] = 'steam'
request_params['filter'] = 'all'
#request_params['day_range'] = '14'

# %%
review_dict, query_count = steamreviews.download_reviews_for_app_id_batch(app_list_specific,
                                                                    chosen_request_params=request_params)
# Out:
# Loading idprocessed_on_20230215.txt
# ...
# [appID = 730] expected #reviews = 1107779
# [appID = 730] num_reviews = 1333 (expected: 1107779)
# ...
# [appID = 1085660] expected #reviews = 67061
# [appID = 1085660] num_reviews = 133 (expected: 67061)
# ...
# [appID = 1599340] expected #reviews = 38201
# [appID = 1599340] num_reviews = 209 (expected: 38201)
# ...
# [appID = 489830] expected #reviews = 77395
# [appID = 489830] num_reviews = 204 (expected: 77395)
# ...
# [appID = 1172470] expected #reviews = 838
# [appID = 1172470] num_reviews = 7 (expected: 838)
# Game records written: 5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [66], in <cell line: 1>()
# ----> 1 review_dict, query_count = steamreviews.download_reviews_for_app_id_batch(app_list_specific,
#       2                                                                     chosen_request_params=request_params)
#
# ...

# %%
csgo = pd.read_json('data/review_730.json')

# %%
#csgo

# %%
csgo = pd.DataFrame(dict(csgo.reviews)).T

# %%
#csgo

# %%
csgo = csgo.dropna()

# %%
csgo.head(3)
# Out:
#           recommendationid                                             author  \
# 131335918        131335918  {'steamid': '76561198388416030', 'num_games_ow...
# 132071116        132071116  {'steamid': '76561198799665922', 'num_games_ow...
# 131494754        131494754  {'steamid': '76561197981851340', 'num_games_ow...
#
#           language                                             review  \
# 131335918  english  Your team in every random competitive game:\n\...
# 132071116  english                     [h1][b]I NOT CAN PLAY[/b][/h1]
# 131494754  english  The best part of this game is when you finally...
#
#           timestamp_created timestamp_updated voted_up votes_up votes_funny  \
# 131335918        1674392512        1674814908     True     2148         599
# 132071116        1675354712        1675356498    False     1071         218
# 131494754        1674607943        1674607943    False      183          47
#
# ...

# %%
csgo.review
# Out:
# 131335918    Your team in every random competitive game:\n\...
# 132071116                       [h1][b]I NOT CAN PLAY[/b][/h1]
# 131494754    The best part of this game is when you finally...
# 132486071    For the optimal experiences play in silver ran...
# 131190045                              CS: Lets GOOOOOOOOOOOOO
#                                    ...
# 126609352                                         csgo > jesus
# 127352623                                                jelek
# 127828365                                   best fps ever made
# 130178929                         Honestly, not the best game.
# 128514412               I am very licky and make lots of money
# Name: review, Length: 1333, dtype: object

# %%
go_review_list = list(csgo.review)

# %%
csgo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1333 entries, 131335918 to 128514412
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   recommendationid             1333 non-null   object
#  1   author                       1333 non-null   object
#  2   language                     1333 non-null   object
#  3   review                       1333 non-null   object
#  4   timestamp_created            1333 non-null   object
#  5   timestamp_updated            1333 non-null   object
#  6   voted_up                     1333 non-null   object
#  7   votes_up                     1333 non-null   object
#  8   votes_funny                  1333 non-null   object
#  9   weighted_vote_score          1333 non-null   object
#  10  comment_count                1333 non-null   object
#  11  steam_purchase               1333 non-null   object
# ...

# %%
csgo = csgo[['review', 'language']]

# %%
csgo
# Out:
#                                                       review language
# 131335918  Your team in every random competitive game:\n\...  english
# 132071116                     [h1][b]I NOT CAN PLAY[/b][/h1]  english
# 131494754  The best part of this game is when you finally...  english
# 132486071  For the optimal experiences play in silver ran...  english
# 131190045                            CS: Lets GOOOOOOOOOOOOO  english
# ...                                                      ...      ...
# 126609352                                       csgo > jesus  english
# 127352623                                              jelek  english
# 127828365                                 best fps ever made  english
# 130178929                       Honestly, not the best game.  english
# 128514412             I am very licky and make lots of money  english
#
# [1333 rows x 2 columns]

# %%
csgo = p.prep_readme_data(csgo, 'review')

# %%
csgo
# Out:
#                                                       review language  \
# 131335918  Your team in every random competitive game:\n\...    Other
# 132071116                     [h1][b]I NOT CAN PLAY[/b][/h1]    Other
# 131494754  The best part of this game is when you finally...    Other
# 132486071  For the optimal experiences play in silver ran...    Other
# 131190045                            CS: Lets GOOOOOOOOOOOOO    Other
# ...                                                      ...      ...
# 126609352                                       csgo > jesus    Other
# 127352623                                              jelek    Other
# 127828365                                 best fps ever made    Other
# 130178929                       Honestly, not the best game.    Other
# 128514412             I am very licky and make lots of money    Other
#
#                                                        clean  \
# 131335918  team every random competitive game russian guy...
# ...

# %%
importlib.reload(explore)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [93], in <cell line: 1>()
# ----> 1 importlib.reload(explore)
#
# NameError: name 'explore' is not defined

# %%
e.get_top10_python(csgo.lemmatized)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'language'
#
# The above exception was the direct cause of the following exception:
#
# ...
